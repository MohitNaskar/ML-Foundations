# %%
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df= sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
encoder = LabelEncoder()
df['species'] = encoder.fit_transform(df['species'])
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
df = df[['sepal_length','petal_length', 'species']]
df.head()
# Out:
#    sepal_length  petal_length  species
# 0           5.1           1.4        0
# 1           4.9           1.4        0
# 2           4.7           1.3        0
# 3           4.6           1.5        0
# 4           5.0           1.4        0

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,2]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)
clf = LogisticRegression()
clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       0.86      1.00      0.92         6
#            2       1.00      0.91      0.95        11
#
#     accuracy                           0.97        30
#    macro avg       0.95      0.97      0.96        30
# weighted avg       0.97      0.97      0.97        30
#
# [[13  0  0]
#  [ 0  6  0]
#  [ 0  1 10]]

# %%
from sklearn.metrics import accuracy_score


print(accuracy_score(y_test,y_pred))
# Out:
# 0.9666666666666667

# %%
# %pip install mlxtend
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X_train.values, y_train.values, clf=clf, legend=2)
plt.xlabel('sepal_length')
plt.ylabel('petal_length')
plt.title('Logistic Regression Decision Boundary')
plt.show()
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.24.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.16.3 in /Users/I578070/Desktop/100DaysML/venv/lib/python3.12/site-packages (from mlxtend) (1.17.1)
# Collecting numpy>=2.3.5 (from mlxtend)
#   Downloading numpy-2.4.4-cp312-cp312-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: pandas>=2.3.3 in /Users/I578070/Desktop/100DaysML/venv/lib/python3.12/site-packages (from mlxtend) (3.0.2)
# Requirement already satisfied: scikit-learn>=1.8.0 in /Users/I578070/Desktop/100DaysML/venv/lib/python3.12/site-packages (from mlxtend) (1.8.0)
# Requirement already satisfied: matplotlib>=3.10.8 in /Users/I578070/Desktop/100DaysML/venv/lib/python3.12/site-packages (from mlxtend) (3.10.9)
# Requirement already satisfied: joblib>=1.5.2 in /Users/I578070/Desktop/100DaysML/venv/lib/python3.12/site-packages (from mlxtend) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/I578070/Desktop/100DaysML/venv/lib/python3.12/site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/I578070/Desktop/100DaysML/venv/lib/python3.12/site-packages (from matplotlib>=3.10.8->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/I578070/Desktop/100DaysML/venv/lib/python3.12/site-packages (from matplotlib>=3.10.8->mlxtend) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/I578070/Desktop/100DaysML/venv/lib/python3.12/site-packages (from matplotlib>=3.10.8->mlxtend) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/I578070/Desktop/100DaysML/venv/lib/python3.12/site-packages (from matplotlib>=3.10.8->mlxtend) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/I578070/Desktop/100DaysML/venv/lib/python3.12/site-packages (from matplotlib>=3.10.8->mlxtend) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /Users/I578070/Desktop/100DaysML/venv/lib/python3.12/site-packages (from matplotlib>=3.10.8->mlxtend) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/I578070/Desktop/100DaysML/venv/lib/python3.12/site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/I578070/Desktop/100DaysML/venv/lib/python3.12/site-packages (from scikit-learn>=1.8.0->mlxtend) (3.6.0)
# Requirement already satisfied: six>=1.5 in /Users/I578070/Desktop/100DaysML/venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.17.0)
# Downloading mlxtend-0.24.0-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 3.1 MB/s eta 0:00:00a 0:00:01
# Downloading numpy-2.4.4-cp312-cp312-macosx_14_0_arm64.whl (5.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 5.5 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: numpy, mlxtend
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# Successfully installed mlxtend-0.24.0 numpy-2.4.4
#
# [notice] A new release of pip is available: 24.2 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# /Users/I578070/Desktop/100DaysML/venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
